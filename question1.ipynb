# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
csv420 = "Resources/420.csv"
df420 = pd.read_csv(csv420)
df420
# Out:
#       Unnamed: 0  year state_abbr state_name  population  violent_crime  \
# 0              0  1979         AK     Alaska      406000           1994
# 1              1  1980         AK     Alaska      440142           1919
# 2              2  1981         AK     Alaska      412000           2537
# 3              3  1982         AK     Alaska      438000           2732
# 4              4  1983         AK     Alaska      479000           2940
# ...          ...   ...        ...        ...         ...            ...
# 2035        2035  2014         WY    Wyoming      584304           1142
# 2036        2036  2015         WY    Wyoming      586555           1300
# 2037        2037  2016         WY    Wyoming      584910           1431
# 2038        2038  2017         WY    Wyoming      578934           1358
# 2039        2039  2018         WY    Wyoming      577601           1235
#
#       homicide  rape_legacy  rape_revised  robbery  ...  burglary  larceny  \
# 0           54        292.0           NaN      445  ...      5616    15076
# 1           39        250.0           NaN      360  ...      5545    14916
# 2           60        421.0           NaN      472  ...      5479    16310
# 3           81        374.0           NaN      586  ...      5204    16672
# 4           66        486.0           NaN      465  ...      5720    17085
# ...        ...          ...           ...      ...  ...       ...      ...
# 2035        16        127.0         174.0       53  ...      1689     9185
# 2036        16        124.0         171.0       59  ...      1762     8797
# 2037        20        152.0         206.0       59  ...      1771     8889
# 2038        14          NaN         253.0       98  ...      1556     8211
# 2039        14          NaN         261.0       75  ...      1551     7974
#
#       motor_vehicle_theft   Legal Status  Medicinal Decriminalized  \
# 0                    2501    Fully Legal        Yes            Yes
# 1                    2469    Fully Legal        Yes            Yes
# 2                    2845    Fully Legal        Yes            Yes
# 3                    2603    Fully Legal        Yes            Yes
# 4                    3084    Fully Legal        Yes            Yes
# ...                   ...            ...        ...            ...
# 2035                  603  Fully Illegal         No             No
# 2036                  592  Fully Illegal         No             No
# 2037                  800  Fully Illegal         No             No
# 2038                  761  Fully Illegal         No             No
# 2039                  783  Fully Illegal         No             No
#
#      Recreational Year legalized (Rec) Medical  Year legalized (Med)
# 0             Yes                 2014     Yes                  1998
# 1             Yes                 2014     Yes                  1998
# 2             Yes                 2014     Yes                  1998
# 3             Yes                 2014     Yes                  1998
# 4             Yes                 2014     Yes                  1998
# ...           ...                  ...     ...                   ...
# 2035           No                    0      No                     0
# 2036           No                    0      No                     0
# 2037           No                    0      No                     0
# 2038           No                    0      No                     0
# 2039           No                    0      No                     0
#
# [2040 rows x 22 columns]

# %%
#loop to populate year legal
true_legality = []

for row in df420.iterrows():
    if row[1]['Year legalized (Rec)'] == 0 and row[1]['Year legalized (Med)'] == 0:
        true_legality.append('Illegal')
    elif row[1]['year'] >= row[1]['Year legalized (Rec)'] and row[1]['Year legalized (Rec)'] != 0:
        true_legality.append('Recreational')
    elif row[1]['year'] >= row[1]['Year legalized (Med)'] and row[1]['Year legalized (Med)'] != 0:
        true_legality.append('Medical')
    else:
        true_legality.append('Illegal')


df420['Adj Legal Status'] = true_legality
df420.head()
# Out:
#    Unnamed: 0  year state_abbr state_name  population  violent_crime  \
# 0           0  1979         AK     Alaska      406000           1994
# 1           1  1980         AK     Alaska      440142           1919
# 2           2  1981         AK     Alaska      412000           2537
# 3           3  1982         AK     Alaska      438000           2732
# 4           4  1983         AK     Alaska      479000           2940
#
#    homicide  rape_legacy  rape_revised  robbery  ...  larceny  \
# 0        54        292.0           NaN      445  ...    15076
# 1        39        250.0           NaN      360  ...    14916
# 2        60        421.0           NaN      472  ...    16310
# 3        81        374.0           NaN      586  ...    16672
# 4        66        486.0           NaN      465  ...    17085
#
#    motor_vehicle_theft  Legal Status  Medicinal  Decriminalized Recreational  \
# 0                 2501   Fully Legal        Yes             Yes          Yes
# 1                 2469   Fully Legal        Yes             Yes          Yes
# 2                 2845   Fully Legal        Yes             Yes          Yes
# 3                 2603   Fully Legal        Yes             Yes          Yes
# 4                 3084   Fully Legal        Yes             Yes          Yes
#
#   Year legalized (Rec) Medical Year legalized (Med)  Adj Legal Status
# 0                 2014     Yes                 1998           Illegal
# 1                 2014     Yes                 1998           Illegal
# 2                 2014     Yes                 1998           Illegal
# 3                 2014     Yes                 1998           Illegal
# 4                 2014     Yes                 1998           Illegal
#
# [5 rows x 23 columns]

# %%
# In order to get the crime rate, for each year, take column with the crime type and divide by the stae population for that year

violent_crime_rate = df420["violent_crime"] / df420["population"]
# violent_crime_rate

property_crime_rate = df420["property_crime"] / df420["population"]
# property_crime_rate

total_crime_rate = (df420["violent_crime"] + df420["property_crime"]) / df420["population"]

# %%
# Compile new Dataframe with State, State Type, Year, Crime Rates, Year Legalized (rec), Year Legalized (med), decriminalized
crime_rate_df = pd.DataFrame({
    "State":df420["state_name"],  
    "Year":df420["year"],
    "Legal Status":df420["Adj Legal Status"],
    "Population":df420["population"],
    "Decriminalized":df420["Decriminalized"], 
    "Violent Crime Rate":violent_crime_rate, 
    "Property Crime Rate":property_crime_rate,
    "Total Crime Rate":total_crime_rate})


# crime_rate_df['Legal Status'] = crime_rate_df['Legal Status'].astype('string')
crime_rate_1990 = crime_rate_df.loc[crime_rate_df['Year']==1990]
crime_rate_2000 = crime_rate_df.loc[crime_rate_df['Year']==2000]
crime_rate_2010 = crime_rate_df.loc[crime_rate_df['Year']==2010]

crime_rate_df
# Out:
#         State  Year Legal Status  Population Decriminalized  \
# 0      Alaska  1979      Illegal      406000            Yes
# 1      Alaska  1980      Illegal      440142            Yes
# 2      Alaska  1981      Illegal      412000            Yes
# 3      Alaska  1982      Illegal      438000            Yes
# 4      Alaska  1983      Illegal      479000            Yes
# ...       ...   ...          ...         ...            ...
# 2035  Wyoming  2014      Illegal      584304             No
# 2036  Wyoming  2015      Illegal      586555             No
# 2037  Wyoming  2016      Illegal      584910             No
# 2038  Wyoming  2017      Illegal      578934             No
# 2039  Wyoming  2018      Illegal      577601             No
#
#       Violent Crime Rate  Property Crime Rate  Total Crime Rate
# 0               0.004911             0.057126          0.062037
# 1               0.004360             0.052097          0.056457
# 2               0.006158             0.059791          0.065949
# 3               0.006237             0.055888          0.062126
# 4               0.006138             0.054048          0.060186
# ...                  ...                  ...               ...
# 2035            0.001954             0.019642          0.021597
# 2036            0.002216             0.019011          0.021227
# 2037            0.002447             0.019593          0.022039
# 2038            0.002346             0.018185          0.020531
# 2039            0.002138             0.017846          0.019984
#
# [2040 rows x 8 columns]

# %%
crime_df_1990 = crime_rate_df.loc[crime_rate_df['Year'] == 1990]
population_1990 = crime_df_1990.groupby(['Legal Status']).sum()

crime_df_2000 = crime_rate_df.loc[crime_rate_df['Year'] == 2000]
population_2000 = crime_df_2000.groupby(['Legal Status']).sum()

crime_df_2010 = crime_rate_df.loc[crime_rate_df['Year'] == 2010]
population_2010 = crime_df_2010.groupby(['Legal Status']).sum()

crime_df_2018 = crime_rate_df.loc[crime_rate_df['Year'] == 2018]
population_2018 = crime_df_2018.groupby(['Legal Status']).sum()


pop_summary_df = pd.DataFrame({ 
    "1990":population_1990["Population"], 
    "2000":population_2000["Population"],
    "2010":population_2010["Population"],
    "2018":population_2018["Population"]
    })

pop_summary_df2 = pop_summary_df.transpose()
pop_summary_df2
# Out:
#           Illegal      Medical  Recreational
# 1990  248709873.0          NaN           NaN
# 2000  228821828.0   52600078.0           NaN
# 2010  220428678.0   88901541.0           NaN
# 2018   92243919.0  154915161.0    79528421.0

# %%
# #Stacked bar of populatio
axes = pop_summary_df2.plot.bar(rot=0, subplots=False, stacked=True)
axes.set_xlabel('Year')
axes.set_ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')
